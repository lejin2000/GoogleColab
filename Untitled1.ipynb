# %%
from google.colab import drive
import os

if not os.path.ismount('/content/drive'):
    drive.mount('/content/drive')
    print("✅ Drive mounted successfully")
else:
    print("✅ Drive already mounted, skipping...")
# Out:
# Mounted at /content/drive
# ✅ Drive mounted successfully

# %%
import os

# List files in a specific folder
path = "/content/drive/MyDrive/"
files = os.listdir(path)
print(files)

# Walk through ALL subdirectories recursively
for root, dirs, files in os.walk("/content/drive/MyDrive/Colab Notebooks"):
    for f in files:
        print(os.path.join(root, f))
# Out:
# ['Colab Notebooks', 'Datasets', 'Google AI Studio', 'GoogleDrive_Owncloud', 'Antigravity']
# /content/drive/MyDrive/Colab Notebooks/oo_config.ipynb
# /content/drive/MyDrive/Colab Notebooks/notebook_databricks_connect_test_spark.ipynb
# /content/drive/MyDrive/Colab Notebooks/notebook_databrick_connect_test.ipynb
# /content/drive/MyDrive/Colab Notebooks/notebook_earhquake_spark.ipynb
# /content/drive/MyDrive/Colab Notebooks/notebook_earhquake.ipynb
# /content/drive/MyDrive/Colab Notebooks/notebook_Test_MinIo.ipynb
# /content/drive/MyDrive/Colab Notebooks/notebook_panda_chart.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled0.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled1.ipynb
