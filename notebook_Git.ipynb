# %%
from google.colab import drive
import os

if not os.path.ismount('/content/drive'):
    drive.mount('/content/drive')
    print("✅ Drive mounted successfully")
else:
    print("✅ Drive already mounted, skipping...")
# Out:
# Mounted at /content/drive
# ✅ Drive mounted successfully

# %%
#configuration notebook

import os
os.chdir("/content/drive/My Drive/Colab Notebooks")
# %run oo_config.ipynb

# %%
#Recurrent commit of git

# Configure identity
# !git config --global user.email G_USER_EMAIL
# !git config --global user.name G_USER_NAME

# Store token as a variable
TOKEN = G_TOKEN
REPO = G_REPO

# !git remote set-url origin https://{TOKEN}@github.com/{REPO}.git


# Set branch
# !git branch -M main

# !git add . ':!oo_config.ipynb'
commit_message = input("Enter commit message: ")
# !git commit -m commit_message #"your message"
# Push
# !git push -u origin main
# Out:
# Enter commit message: fix yahoo for SGX  share
# [main f9263a5] commit_message
#  6 files changed, 6 insertions(+), 5 deletions(-)
#  rewrite notebook_Git.ipynb (63%)
#  rewrite notebook_cgs_read_minio_spark_yahoo.ipynb (95%)
#  rewrite notebook_earthquake_multi_files_fix_filename.ipynb (90%)
#  rewrite notebook_earthquake_read_minio_spark.ipynb (91%)
#  rewrite notebook_hlebroking_minio.ipynb (97%)
#  create mode 100644 notebook_yahoo_query.ipynb
# Enumerating objects: 14, done.
# Counting objects: 100% (14/14), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (8/8), 9.88 KiB | 374.00 KiB/s, done.
# Total 8 (delta 6), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (6/6), completed with 6 local objects.
# To https://github.com/lejin2000/GoogleColab.git
#    4853c4f..f9263a5  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# %%script echo "Skipping..."
# import os
#
# # List files in a specific folder
# path = "/content/drive/MyDrive/"
# files = os.listdir(path)
# print(files)
#
# # Walk through ALL subdirectories recursively
# for root, dirs, files in os.walk("/content/drive/MyDrive/Colab Notebooks"):
#     for f in files:
#         print(os.path.join(root, f))
# Out:
# Skipping...
