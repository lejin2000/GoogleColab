# %%
from google.colab import drive
import os

if not os.path.ismount('/content/drive'):
    drive.mount('/content/drive')
    print("✅ Drive mounted successfully")
else:
    print("✅ Drive already mounted, skipping...")
# Out:
# Mounted at /content/drive
# ✅ Drive mounted successfully

# %%
#configuration notebook

import os
os.chdir("/content/drive/My Drive/Colab Notebooks")
# %run oo_config.ipynb

# %%
#Recurrent commit of git

# Configure identity
# !git config --global user.email G_USER_EMAIL
# !git config --global user.name G_USER_NAME

# Store token as a variable
TOKEN = G_TOKEN
REPO = G_REPO

# !git remote set-url origin https://{TOKEN}@github.com/{REPO}.git


# Set branch
# !git branch -M main

# !git add . ':!oo_config.ipynb'
# !git commit -m "add new earthquake save to databricks" #"your message"
# Push
# !git push -u origin main
# Out:
# [main a3257bd] add new earthquake save to databricks
#  4 files changed, 4 insertions(+), 2 deletions(-)
#  rewrite notebook_Git.ipynb (65%)
#  create mode 100644 notebook_aviationstack.ipynb
#  rewrite notebook_earthquake_multi_files_fix_filename.ipynb (96%)
#  create mode 100644 notebook_minio_spark_cgs.ipynb
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 19.62 KiB | 1.03 MiB/s, done.
# Total 6 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/lejin2000/GoogleColab.git
#    63228c5..a3257bd  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# %%script echo "Skipping..."
# import os
#
# # List files in a specific folder
# path = "/content/drive/MyDrive/"
# files = os.listdir(path)
# print(files)
#
# # Walk through ALL subdirectories recursively
# for root, dirs, files in os.walk("/content/drive/MyDrive/Colab Notebooks"):
#     for f in files:
#         print(os.path.join(root, f))
# Out:
# Skipping...
