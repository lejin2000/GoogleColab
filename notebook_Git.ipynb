# %%
from google.colab import drive
import os

if not os.path.ismount('/content/drive'):
    drive.mount('/content/drive')
    print("✅ Drive mounted successfully")
else:
    print("✅ Drive already mounted, skipping...")
# Out:
# ✅ Drive already mounted, skipping...

# %%
#configuration notebook

import os
os.chdir("/content/drive/My Drive/Colab Notebooks")
# %run oo_config.ipynb

# %%
#Recurrent commit of git

# Configure identity
# !git config --global user.email G_USER_EMAIL
# !git config --global user.name G_USER_NAME

# Store token as a variable
TOKEN = G_TOKEN
REPO = G_REPO

# !git remote set-url origin https://{TOKEN}@github.com/{REPO}.git


# Set branch
# !git branch -M main

# !git add . ':!oo_config.ipynb'
# !git commit -m "add new hlebreoking  minio" #"your message"
# Push
# !git push -u origin main
# Out:
# [main 8b6310f] add new hlebreoking  minio
#  5 files changed, 5 insertions(+), 3 deletions(-)
#  rewrite notebook_Git.ipynb (86%)
#  rewrite notebook_cgs_read_minio_spark_yahoo.ipynb (96%)
#  rewrite notebook_earthquake_multi_files_fix_filename.ipynb (90%)
#  create mode 100644 notebook_hlebroking_minio.ipynb
#  create mode 100644 notebook_test_datetime_re.ipynb
# Enumerating objects: 11, done.
# Counting objects: 100% (11/11), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 14.94 KiB | 728.00 KiB/s, done.
# Total 7 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 3 local objects.
# To https://github.com/lejin2000/GoogleColab.git
#    df75ce1..8b6310f  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# %%script echo "Skipping..."
# import os
#
# # List files in a specific folder
# path = "/content/drive/MyDrive/"
# files = os.listdir(path)
# print(files)
#
# # Walk through ALL subdirectories recursively
# for root, dirs, files in os.walk("/content/drive/MyDrive/Colab Notebooks"):
#     for f in files:
#         print(os.path.join(root, f))
# Out:
# Skipping...
