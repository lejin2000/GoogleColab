# %%
from google.colab import drive
import os

if not os.path.ismount('/content/drive'):
    drive.mount('/content/drive')
    print("✅ Drive mounted successfully")
else:
    print("✅ Drive already mounted, skipping...")
# Out:
# Mounted at /content/drive
# ✅ Drive mounted successfully

# %%
#configuration notebook

import os
os.chdir("/content/drive/My Drive/Colab Notebooks")
# %run oo_config.ipynb

# %%
#Recurrent commit of git

# Configure identity
# !git config --global user.email G_USER_EMAIL
# !git config --global user.name G_USER_NAME

# Store token as a variable
TOKEN = G_TOKEN
REPO = G_REPO

# !git remote set-url origin https://{TOKEN}@github.com/{REPO}.git


# Set branch
# !git branch -M main

# !git add . ':!oo_config.ipynb'
# !git commit -m "add new earthquake notebook" #"your message"
# Push
# !git push -u origin main
# Out:
# [main ffe3ab7] add new earthquake notebook
#  5 files changed, 5 insertions(+), 2 deletions(-)
#  rewrite notebook_Git.ipynb (94%)
#  rewrite notebook_earhquake_spark.ipynb (95%)
#  create mode 100644 notebook_earthquake_multi_files_fix_filename.ipynb
#  create mode 100644 notebook_earthquake_spark_multi_files.ipynb
#  create mode 100644 notebook_read_minio_spark.ipynb
# Enumerating objects: 10, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 9.26 KiB | 474.00 KiB/s, done.
# Total 7 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 2 local objects.
# To https://github.com/lejin2000/GoogleColab.git
#    87c41c9..ffe3ab7  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# %%script echo "Skipping..."
# import os
#
# # List files in a specific folder
# path = "/content/drive/MyDrive/"
# files = os.listdir(path)
# print(files)
#
# # Walk through ALL subdirectories recursively
# for root, dirs, files in os.walk("/content/drive/MyDrive/Colab Notebooks"):
#     for f in files:
#         print(os.path.join(root, f))
# Out:
# Skipping...
