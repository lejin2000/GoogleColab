# %%
from google.colab import drive
import os

if not os.path.ismount('/content/drive'):
    drive.mount('/content/drive')
    print("✅ Drive mounted successfully")
else:
    print("✅ Drive already mounted, skipping...")
# Out:
# ✅ Drive already mounted, skipping...

# %%
#configuration notebook

import os
os.chdir("/content/drive/My Drive/Colab Notebooks")
# %run oo_config.ipynb

# %%
#Recurrent commitof git

# Configure identity
# !git config --global user.email G_USER_EMAIL
# !git config --global user.name G_USER_NAME

# !git add . ':!oo_config.ipynb'

# !git commit -m "added notebook_read_files" #"your message"

# Set branch
# !git branch -M main

# Store token as a variable
TOKEN = G_TOKEN
REPO = G_REPO

# Inject into git command using f-string
# !git remote add origin https://{TOKEN}@github.com/{REPO}.git

# Push
# !git push -u origin main
# Out:
# [main 3d91f71] added notebook_read_files
#  2 files changed, 1 insertion(+), 1 deletion(-)
#  delete mode 100644 Untitled1.ipynb
#  create mode 100644 notebook_read_files.ipynb
# error: remote origin already exists.
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# %%script echo "Skipping..."
# import os
#
# # List files in a specific folder
# path = "/content/drive/MyDrive/"
# files = os.listdir(path)
# print(files)
#
# # Walk through ALL subdirectories recursively
# for root, dirs, files in os.walk("/content/drive/MyDrive/Colab Notebooks"):
#     for f in files:
#         print(os.path.join(root, f))
# Out:
# Skipping...
