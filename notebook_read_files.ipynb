# %%
from google.colab import drive
import os

if not os.path.ismount('/content/drive'):
    drive.mount('/content/drive')
    print("✅ Drive mounted successfully")
else:
    print("✅ Drive already mounted, skipping...")
# Out:
# ✅ Drive already mounted, skipping...

# %%
#configuration notebook

import os
os.chdir("/content/drive/My Drive/Colab Notebooks")
# %run oo_config.ipynb

# %%
#Recurrent commit of git

# Configure identity
# !git config --global user.email G_USER_EMAIL
# !git config --global user.name G_USER_NAME

# Store token as a variable
TOKEN = G_TOKEN
REPO = G_REPO

# !git remote set-url origin https://{TOKEN}@github.com/{REPO}.git


# Set branch
# !git branch -M main

# !git add . ':!oo_config.ipynb'
# !git commit -m "deleted untitle" #"your message"
# Push
# !git push -u origin main
# Out:
# [main 4e131e2] deleted untitle
#  2 files changed, 1 insertion(+), 2 deletions(-)
#  delete mode 100644 Untitled0.ipynb
#  rewrite notebook_read_files.ipynb (94%)
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 902 bytes | 180.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/lejin2000/GoogleColab.git
#    86b6322..4e131e2  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# %%script echo "Skipping..."
# import os
#
# # List files in a specific folder
# path = "/content/drive/MyDrive/"
# files = os.listdir(path)
# print(files)
#
# # Walk through ALL subdirectories recursively
# for root, dirs, files in os.walk("/content/drive/MyDrive/Colab Notebooks"):
#     for f in files:
#         print(os.path.join(root, f))
# Out:
# Skipping...
